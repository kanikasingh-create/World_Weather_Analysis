# %%
# Import all dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
import time 
from scipy.stats import linregress

# %%
# Generate a new set of 1,500 random latitudes and longitudes.

latitudes = np.random.uniform(low = -90, high = 90, size = 1500)
longitudes = np.random.uniform (low = -180, high = 180, size = 1500)
latitudes_longitudes = zip(latitudes,longitudes)
latitudes_longitudes

# %%
# Unpack longitudes and latitudes, and place in a list. 
coordinates = list(latitudes_longitudes)
len(coordinates)
# Out:
# 1500

# %%
# Get the nearest city using the citipy module.
# Create a list to hold all city names nearest to the generated coordinates.
cities = []

# Identify the nearest city for each latitude and longitutde combo.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    # if city is unique then add to the cities list.
    if city not in cities:
        cities.append(city)
    
len(cities)
# Out:
# 588

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bdade31150689958c7633db25fbfdd40"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bdade31150689958c7633db25fbfdd40

# %%
# Create an empty list to hold weather data for cities.

city_data = []

# Print the begining of logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1

set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        try:
            city_rain = city_weather["rain"]["3h"]
        except:
            city_rain = 0
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain inches (last 3 hrs)": city_rain,
                          "Snow inches (last 3 hrs)": city_snow})
    
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass 
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | longyearbyen
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | show low
# Processing Record 6 of Set 1 | saskylakh
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | san cristobal
# Processing Record 10 of Set 1 | sao filipe
# Processing Record 11 of Set 1 | esperance
# Processing Record 12 of Set 1 | upernavik
# Processing Record 13 of Set 1 | rolim de moura
# City not found. Skipping...
# Processing Record 14 of Set 1 | nurlat
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | oranjemund
# Processing Record 17 of Set 1 | honningsvag
# Processing Record 18 of Set 1 | iqaluit
# Processing Record 19 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | bambous virieux
# Processing Record 22 of Set 1 | imbituba
# Processing Record 23 of Set 1 | katha
# City not found. Skipping...
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | la rioja
# Processing Record 27 of Set 1 | ust-ishim
# Processing Record 28 of Set 1 | parbhani
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | pontiac
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | baykit
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | odweyne
# Processing Record 36 of Set 1 | tres arroyos
# Processing Record 37 of Set 1 | pangai
# Processing Record 38 of Set 1 | vila franca do campo
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | tilichiki
# Processing Record 41 of Set 1 | kudahuvadhoo
# Processing Record 42 of Set 1 | kamenka
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | macas
# Processing Record 48 of Set 1 | xuddur
# Processing Record 49 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 1 | conway
# Processing Record 1 of Set 2 | makokou
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | sinnamary
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | narsaq
# Processing Record 7 of Set 2 | parabel
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | abreus
# Processing Record 10 of Set 2 | chokurdakh
# Processing Record 11 of Set 2 | bardiyah
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | tacoronte
# Processing Record 14 of Set 2 | moree
# Processing Record 15 of Set 2 | lotofaga
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | contamana
# Processing Record 18 of Set 2 | bundaberg
# Processing Record 19 of Set 2 | victoria
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | erdenet
# Processing Record 23 of Set 2 | udachnyy
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | saint-philippe
# Processing Record 26 of Set 2 | pulaski
# Processing Record 27 of Set 2 | leningradskiy
# Processing Record 28 of Set 2 | ocos
# Processing Record 29 of Set 2 | alofi
# Processing Record 30 of Set 2 | kathmandu
# Processing Record 31 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 2 | chapais
# Processing Record 33 of Set 2 | makakilo city
# Processing Record 34 of Set 2 | chingirlau
# Processing Record 35 of Set 2 | cherskiy
# Processing Record 36 of Set 2 | svolvaer
# Processing Record 37 of Set 2 | altay
# Processing Record 38 of Set 2 | conceicao do araguaia
# Processing Record 39 of Set 2 | tazovskiy
# Processing Record 40 of Set 2 | half moon bay
# Processing Record 41 of Set 2 | artesia
# Processing Record 42 of Set 2 | vaini
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | minsk
# Processing Record 45 of Set 2 | neringa
# Processing Record 46 of Set 2 | duldurga
# Processing Record 47 of Set 2 | crab hill
# City not found. Skipping...
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | katsuura
# Processing Record 1 of Set 3 | fairbanks
# Processing Record 2 of Set 3 | seguela
# Processing Record 3 of Set 3 | airai
# Processing Record 4 of Set 3 | asaba
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | san patricio
# Processing Record 7 of Set 3 | great yarmouth
# Processing Record 8 of Set 3 | saint-pierre
# Processing Record 9 of Set 3 | saint george
# Processing Record 10 of Set 3 | meulaboh
# Processing Record 11 of Set 3 | jinhua
# Processing Record 12 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 3 | point fortin
# Processing Record 14 of Set 3 | svetlaya
# Processing Record 15 of Set 3 | gravelbourg
# Processing Record 16 of Set 3 | dikson
# Processing Record 17 of Set 3 | barrow
# Processing Record 18 of Set 3 | rocha
# Processing Record 19 of Set 3 | rongcheng
# Processing Record 20 of Set 3 | avarua
# Processing Record 21 of Set 3 | berlevag
# Processing Record 22 of Set 3 | puerto escondido
# Processing Record 23 of Set 3 | albany
# Processing Record 24 of Set 3 | carbonia
# Processing Record 25 of Set 3 | bilibino
# Processing Record 26 of Set 3 | zeya
# Processing Record 27 of Set 3 | westport
# Processing Record 28 of Set 3 | caravelas
# Processing Record 29 of Set 3 | tecoanapa
# Processing Record 30 of Set 3 | kaitangata
# Processing Record 31 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 3 | ancud
# Processing Record 33 of Set 3 | dingle
# Processing Record 34 of Set 3 | alice springs
# Processing Record 35 of Set 3 | skuodas
# Processing Record 36 of Set 3 | mahebourg
# Processing Record 37 of Set 3 | laborie
# Processing Record 38 of Set 3 | ekhabi
# Processing Record 39 of Set 3 | pisco
# Processing Record 40 of Set 3 | bluff
# Processing Record 41 of Set 3 | sitka
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | butaritari
# Processing Record 44 of Set 3 | niamey
# Processing Record 45 of Set 3 | new norfolk
# Processing Record 46 of Set 3 | lodja
# Processing Record 47 of Set 3 | sofiysk
# City not found. Skipping...
# Processing Record 48 of Set 3 | narrabri
# Processing Record 49 of Set 3 | bulgan
# Processing Record 50 of Set 3 | ilulissat
# Processing Record 1 of Set 4 | san policarpo
# Processing Record 2 of Set 4 | mirnyy
# Processing Record 3 of Set 4 | manta
# Processing Record 4 of Set 4 | pevek
# Processing Record 5 of Set 4 | talnakh
# Processing Record 6 of Set 4 | antalaha
# Processing Record 7 of Set 4 | saint anthony
# Processing Record 8 of Set 4 | nantucket
# Processing Record 9 of Set 4 | port elizabeth
# Processing Record 10 of Set 4 | raga
# Processing Record 11 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 4 | marawi
# Processing Record 13 of Set 4 | subacius
# City not found. Skipping...
# Processing Record 14 of Set 4 | taoudenni
# Processing Record 15 of Set 4 | saint-francois
# Processing Record 16 of Set 4 | laguna
# Processing Record 17 of Set 4 | manado
# Processing Record 18 of Set 4 | bethel
# Processing Record 19 of Set 4 | banmo
# City not found. Skipping...
# Processing Record 20 of Set 4 | kavieng
# Processing Record 21 of Set 4 | coahuayana
# Processing Record 22 of Set 4 | hailey
# Processing Record 23 of Set 4 | nisia floresta
# Processing Record 24 of Set 4 | severodvinsk
# Processing Record 25 of Set 4 | topaipi
# Processing Record 26 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 4 | nemuro
# Processing Record 28 of Set 4 | praia
# Processing Record 29 of Set 4 | leh
# Processing Record 30 of Set 4 | provideniya
# Processing Record 31 of Set 4 | goderich
# Processing Record 32 of Set 4 | xingcheng
# Processing Record 33 of Set 4 | north battleford
# Processing Record 34 of Set 4 | prnjavor
# Processing Record 35 of Set 4 | ballina
# Processing Record 36 of Set 4 | daru
# Processing Record 37 of Set 4 | faanui
# Processing Record 38 of Set 4 | tulagi
# Processing Record 39 of Set 4 | ponta do sol
# Processing Record 40 of Set 4 | norman wells
# Processing Record 41 of Set 4 | moron
# Processing Record 42 of Set 4 | cockburn town
# Processing Record 43 of Set 4 | bani
# Processing Record 44 of Set 4 | ituni
# City not found. Skipping...
# Processing Record 45 of Set 4 | vao
# Processing Record 46 of Set 4 | carnarvon
# Processing Record 47 of Set 4 | krasnoselkup
# Processing Record 48 of Set 4 | georgetown
# Processing Record 49 of Set 4 | padang
# Processing Record 50 of Set 4 | chazuta
# Processing Record 1 of Set 5 | anadyr
# Processing Record 2 of Set 5 | asau
# Processing Record 3 of Set 5 | laguna de perlas
# Processing Record 4 of Set 5 | haines junction
# Processing Record 5 of Set 5 | vardo
# Processing Record 6 of Set 5 | mar del plata
# Processing Record 7 of Set 5 | tessalit
# Processing Record 8 of Set 5 | abu jubayhah
# City not found. Skipping...
# Processing Record 9 of Set 5 | lorengau
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | torbay
# Processing Record 12 of Set 5 | kamen-rybolov
# Processing Record 13 of Set 5 | opuwo
# Processing Record 14 of Set 5 | sivaki
# Processing Record 15 of Set 5 | tuatapere
# Processing Record 16 of Set 5 | kaeo
# Processing Record 17 of Set 5 | khandyga
# Processing Record 18 of Set 5 | avera
# Processing Record 19 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 21 of Set 5 | mglin
# Processing Record 22 of Set 5 | ovalle
# Processing Record 23 of Set 5 | iquitos
# Processing Record 24 of Set 5 | seddon
# Processing Record 25 of Set 5 | narok
# Processing Record 26 of Set 5 | touros
# Processing Record 27 of Set 5 | nishihara
# Processing Record 28 of Set 5 | mnogovershinnyy
# Processing Record 29 of Set 5 | junction city
# Processing Record 30 of Set 5 | henties bay
# Processing Record 31 of Set 5 | general roca
# Processing Record 32 of Set 5 | thinadhoo
# Processing Record 33 of Set 5 | taywarah
# Processing Record 34 of Set 5 | jishou
# Processing Record 35 of Set 5 | mukhen
# Processing Record 36 of Set 5 | mariental
# Processing Record 37 of Set 5 | necochea
# Processing Record 38 of Set 5 | husavik
# Processing Record 39 of Set 5 | marienburg
# Processing Record 40 of Set 5 | penzance
# Processing Record 41 of Set 5 | karratha
# Processing Record 42 of Set 5 | malakal
# Processing Record 43 of Set 5 | panjwin
# City not found. Skipping...
# Processing Record 44 of Set 5 | grindavik
# Processing Record 45 of Set 5 | mayumba
# Processing Record 46 of Set 5 | bafata
# Processing Record 47 of Set 5 | xichang
# Processing Record 48 of Set 5 | san jeronimo
# Processing Record 49 of Set 5 | lompoc
# Processing Record 50 of Set 5 | kruisfontein
# Processing Record 1 of Set 6 | kununurra
# Processing Record 2 of Set 6 | khatanga
# Processing Record 3 of Set 6 | verkhoyansk
# Processing Record 4 of Set 6 | kizukuri
# Processing Record 5 of Set 6 | valparaiso
# Processing Record 6 of Set 6 | mildura
# Processing Record 7 of Set 6 | tiksi
# Processing Record 8 of Set 6 | prince rupert
# Processing Record 9 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 6 | lubao
# Processing Record 12 of Set 6 | foz
# Processing Record 13 of Set 6 | jesup
# Processing Record 14 of Set 6 | sola
# Processing Record 15 of Set 6 | dombarovskiy
# Processing Record 16 of Set 6 | oksfjord
# Processing Record 17 of Set 6 | karaton
# Processing Record 18 of Set 6 | bonavista
# Processing Record 19 of Set 6 | kokopo
# Processing Record 20 of Set 6 | grafton
# Processing Record 21 of Set 6 | amherstburg
# Processing Record 22 of Set 6 | san fernando
# Processing Record 23 of Set 6 | praia da vitoria
# Processing Record 24 of Set 6 | kimbe
# Processing Record 25 of Set 6 | kieta
# Processing Record 26 of Set 6 | clyde river
# Processing Record 27 of Set 6 | tuktoyaktuk
# Processing Record 28 of Set 6 | hasaki
# Processing Record 29 of Set 6 | bojnurd
# Processing Record 30 of Set 6 | pangnirtung
# Processing Record 31 of Set 6 | port-gentil
# Processing Record 32 of Set 6 | yeppoon
# Processing Record 33 of Set 6 | ribeira grande
# Processing Record 34 of Set 6 | peace river
# Processing Record 35 of Set 6 | hailar
# Processing Record 36 of Set 6 | baruun-urt
# Processing Record 37 of Set 6 | fortuna
# Processing Record 38 of Set 6 | port macquarie
# Processing Record 39 of Set 6 | requena
# Processing Record 40 of Set 6 | zapolyarnyy
# Processing Record 41 of Set 6 | barhi
# Processing Record 42 of Set 6 | chuy
# Processing Record 43 of Set 6 | bjelovar
# Processing Record 44 of Set 6 | fez
# Processing Record 45 of Set 6 | santa cruz
# Processing Record 46 of Set 6 | sao miguel do araguaia
# Processing Record 47 of Set 6 | vila velha
# Processing Record 48 of Set 6 | cidreira
# Processing Record 49 of Set 6 | arrecife
# Processing Record 50 of Set 6 | dunedin
# Processing Record 1 of Set 7 | gao
# Processing Record 2 of Set 7 | plouzane
# Processing Record 3 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 7 | alyangula
# Processing Record 5 of Set 7 | vila do maio
# Processing Record 6 of Set 7 | lynchburg
# Processing Record 7 of Set 7 | charters towers
# Processing Record 8 of Set 7 | beira
# Processing Record 9 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 10 of Set 7 | inta
# Processing Record 11 of Set 7 | wajima
# Processing Record 12 of Set 7 | cabo san lucas
# Processing Record 13 of Set 7 | aramaywan
# City not found. Skipping...
# Processing Record 14 of Set 7 | chik
# Processing Record 15 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 16 of Set 7 | lavrentiya
# Processing Record 17 of Set 7 | sioux lookout
# Processing Record 18 of Set 7 | nuuk
# Processing Record 19 of Set 7 | castro
# Processing Record 20 of Set 7 | jacareacanga
# Processing Record 21 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 22 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 7 | kidal
# Processing Record 24 of Set 7 | simao
# Processing Record 25 of Set 7 | dudhani
# Processing Record 26 of Set 7 | saldanha
# Processing Record 27 of Set 7 | gavle
# Processing Record 28 of Set 7 | copiapo
# Processing Record 29 of Set 7 | san luis
# Processing Record 30 of Set 7 | east wenatchee bench
# Processing Record 31 of Set 7 | ketchikan
# Processing Record 32 of Set 7 | port hedland
# Processing Record 33 of Set 7 | tzaneen
# Processing Record 34 of Set 7 | rawson
# Processing Record 35 of Set 7 | strezhevoy
# Processing Record 36 of Set 7 | schkeuditz
# Processing Record 37 of Set 7 | fort nelson
# Processing Record 38 of Set 7 | kayerkan
# Processing Record 39 of Set 7 | solnechnyy
# Processing Record 40 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 7 | cheney
# Processing Record 42 of Set 7 | manokwari
# Processing Record 43 of Set 7 | hamilton
# Processing Record 44 of Set 7 | kapoeta
# Processing Record 45 of Set 7 | belmonte
# Processing Record 46 of Set 7 | darhan
# Processing Record 47 of Set 7 | hobyo
# Processing Record 48 of Set 7 | naze
# Processing Record 49 of Set 7 | siocon
# Processing Record 50 of Set 7 | beringovskiy
# Processing Record 1 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 8 | te anau
# Processing Record 3 of Set 8 | mitsamiouli
# Processing Record 4 of Set 8 | vieira de leiria
# Processing Record 5 of Set 8 | xiashi
# Processing Record 6 of Set 8 | bosaso
# Processing Record 7 of Set 8 | guangyuan
# Processing Record 8 of Set 8 | wanlaweyn
# Processing Record 9 of Set 8 | mo i rana
# Processing Record 10 of Set 8 | disraeli
# Processing Record 11 of Set 8 | oparino
# Processing Record 12 of Set 8 | wasilla
# Processing Record 13 of Set 8 | lerwick
# Processing Record 14 of Set 8 | pampas
# Processing Record 15 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 8 | stornoway
# Processing Record 17 of Set 8 | cajititlan
# Processing Record 18 of Set 8 | tsiroanomandidy
# Processing Record 19 of Set 8 | zyryanka
# Processing Record 20 of Set 8 | streator
# Processing Record 21 of Set 8 | tukrah
# Processing Record 22 of Set 8 | carutapera
# Processing Record 23 of Set 8 | chifeng
# Processing Record 24 of Set 8 | nyirtelek
# Processing Record 25 of Set 8 | andenes
# Processing Record 26 of Set 8 | araripe
# Processing Record 27 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 8 | spearfish
# Processing Record 29 of Set 8 | bibiani
# Processing Record 30 of Set 8 | ouallam
# Processing Record 31 of Set 8 | goksun
# Processing Record 32 of Set 8 | kalmunai
# Processing Record 33 of Set 8 | tommot
# Processing Record 34 of Set 8 | korla
# Processing Record 35 of Set 8 | hammerfest
# Processing Record 36 of Set 8 | ozernovskiy
# Processing Record 37 of Set 8 | waitati
# Processing Record 38 of Set 8 | chernyshevskiy
# Processing Record 39 of Set 8 | naliya
# Processing Record 40 of Set 8 | monrovia
# Processing Record 41 of Set 8 | enterprise
# Processing Record 42 of Set 8 | diego de almagro
# Processing Record 43 of Set 8 | manching
# Processing Record 44 of Set 8 | port hardy
# Processing Record 45 of Set 8 | hay river
# Processing Record 46 of Set 8 | olafsvik
# Processing Record 47 of Set 8 | doha
# Processing Record 48 of Set 8 | kungurtug
# Processing Record 49 of Set 8 | adrar
# Processing Record 50 of Set 8 | digras
# Processing Record 1 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 2 of Set 9 | cayenne
# Processing Record 3 of Set 9 | marsa matruh
# Processing Record 4 of Set 9 | fallon
# Processing Record 5 of Set 9 | kangaatsiaq
# Processing Record 6 of Set 9 | lima
# Processing Record 7 of Set 9 | nagato
# Processing Record 8 of Set 9 | severo-kurilsk
# Processing Record 9 of Set 9 | namatanai
# Processing Record 10 of Set 9 | da lat
# Processing Record 11 of Set 9 | maceio
# Processing Record 12 of Set 9 | juneau
# Processing Record 13 of Set 9 | aranos
# Processing Record 14 of Set 9 | bengkulu
# Processing Record 15 of Set 9 | port blair
# Processing Record 16 of Set 9 | yumen
# Processing Record 17 of Set 9 | asfi
# Processing Record 18 of Set 9 | ituango
# Processing Record 19 of Set 9 | teguise
# Processing Record 20 of Set 9 | aswan
# Processing Record 21 of Set 9 | afanasyevo
# City not found. Skipping...
# Processing Record 22 of Set 9 | vila
# Processing Record 23 of Set 9 | barreiras
# Processing Record 24 of Set 9 | lingao
# Processing Record 25 of Set 9 | nidzica
# Processing Record 26 of Set 9 | ginda
# Processing Record 27 of Set 9 | new amsterdam
# Processing Record 28 of Set 9 | hofn
# Processing Record 29 of Set 9 | brewster
# Processing Record 30 of Set 9 | jonesboro
# Processing Record 31 of Set 9 | banda aceh
# Processing Record 32 of Set 9 | ginir
# Processing Record 33 of Set 9 | jieshi
# Processing Record 34 of Set 9 | quatre cocos
# Processing Record 35 of Set 9 | wazzan
# City not found. Skipping...
# Processing Record 36 of Set 9 | souillac
# Processing Record 37 of Set 9 | pasni
# Processing Record 38 of Set 9 | ulkan
# Processing Record 39 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 40 of Set 9 | villarrobledo
# Processing Record 41 of Set 9 | kasane
# Processing Record 42 of Set 9 | talawdi
# City not found. Skipping...
# Processing Record 43 of Set 9 | turlock
# Processing Record 44 of Set 9 | madras
# Processing Record 45 of Set 9 | veraval
# Processing Record 46 of Set 9 | malino
# Processing Record 47 of Set 9 | srandakan
# Processing Record 48 of Set 9 | tigzirt
# Processing Record 49 of Set 9 | north bend
# Processing Record 50 of Set 9 | pacific grove
# Processing Record 1 of Set 10 | olinda
# Processing Record 2 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 3 of Set 10 | fuzhou
# Processing Record 4 of Set 10 | goya
# Processing Record 5 of Set 10 | kashi
# Processing Record 6 of Set 10 | geraldton
# Processing Record 7 of Set 10 | kutum
# Processing Record 8 of Set 10 | basoko
# Processing Record 9 of Set 10 | san quintin
# Processing Record 10 of Set 10 | cururupu
# Processing Record 11 of Set 10 | takayama
# Processing Record 12 of Set 10 | labuhan
# Processing Record 13 of Set 10 | raozan
# City not found. Skipping...
# Processing Record 14 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 10 | coquimbo
# Processing Record 16 of Set 10 | stokmarknes
# Processing Record 17 of Set 10 | pribelskiy
# City not found. Skipping...
# Processing Record 18 of Set 10 | fort pierce
# Processing Record 19 of Set 10 | poum
# Processing Record 20 of Set 10 | ourossogui
# Processing Record 21 of Set 10 | vidim
# Processing Record 22 of Set 10 | tarko-sale
# Processing Record 23 of Set 10 | nianzishan
# Processing Record 24 of Set 10 | storsteinnes
# Processing Record 25 of Set 10 | ixtapa
# Processing Record 26 of Set 10 | kalabo
# Processing Record 27 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 28 of Set 10 | richards bay
# Processing Record 29 of Set 10 | deputatskiy
# Processing Record 30 of Set 10 | sao jose da coroa grande
# Processing Record 31 of Set 10 | mareeba
# Processing Record 32 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 10 | nieves
# Processing Record 34 of Set 10 | maniitsoq
# Processing Record 35 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 10 | la ronge
# Processing Record 37 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 10 | mabaruma
# Processing Record 39 of Set 10 | shingu
# Processing Record 40 of Set 10 | mount isa
# Processing Record 41 of Set 10 | guderup
# Processing Record 42 of Set 10 | bhainsdehi
# Processing Record 43 of Set 10 | buala
# Processing Record 44 of Set 10 | corumba
# Processing Record 45 of Set 10 | maine-soroa
# Processing Record 46 of Set 10 | lethem
# Processing Record 47 of Set 10 | ostersund
# Processing Record 48 of Set 10 | waddan
# Processing Record 49 of Set 10 | marzuq
# Processing Record 50 of Set 10 | knysna
# Processing Record 1 of Set 11 | bathsheba
# Processing Record 2 of Set 11 | sanary-sur-mer
# Processing Record 3 of Set 11 | tucuma
# Processing Record 4 of Set 11 | ust-kut
# Processing Record 5 of Set 11 | mandera
# Processing Record 6 of Set 11 | galveston
# Processing Record 7 of Set 11 | linxia
# Processing Record 8 of Set 11 | zhob
# Processing Record 9 of Set 11 | gaoua
# Processing Record 10 of Set 11 | belaya gora
# Processing Record 11 of Set 11 | burica
# City not found. Skipping...
# Processing Record 12 of Set 11 | siparia
# Processing Record 13 of Set 11 | umm kaddadah
# Processing Record 14 of Set 11 | oshakati
# Processing Record 15 of Set 11 | amga
# Processing Record 16 of Set 11 | nanning
# Processing Record 17 of Set 11 | port moresby
# Processing Record 18 of Set 11 | biao
# Processing Record 19 of Set 11 | bandarbeyla
# Processing Record 20 of Set 11 | gigmoto
# Processing Record 21 of Set 11 | evanston
# Processing Record 22 of Set 11 | ust-kuyga
# Processing Record 23 of Set 11 | jalingo
# Processing Record 24 of Set 11 | constitucion
# Processing Record 25 of Set 11 | kishi
# Processing Record 26 of Set 11 | sambava
# Processing Record 27 of Set 11 | kathu
# Processing Record 28 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 29 of Set 11 | wanaka
# Processing Record 30 of Set 11 | were ilu
# Processing Record 31 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 32 of Set 11 | tongzhou
# Processing Record 33 of Set 11 | barra do garcas
# Processing Record 34 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 11 | seoul
# Processing Record 36 of Set 11 | saint-augustin
# Processing Record 37 of Set 11 | tashara
# Processing Record 38 of Set 11 | marsh harbour
# Processing Record 39 of Set 11 | nago
# Processing Record 40 of Set 11 | viedma
# Processing Record 41 of Set 11 | simbahan
# Processing Record 42 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 43 of Set 11 | cangucu
# Processing Record 44 of Set 11 | margate
# Processing Record 45 of Set 11 | waingapu
# Processing Record 46 of Set 11 | sheboygan
# Processing Record 47 of Set 11 | kundiawa
# Processing Record 48 of Set 11 | saryozek
# Processing Record 49 of Set 11 | mahibadhoo
# Processing Record 50 of Set 11 | amazar
# Processing Record 1 of Set 12 | phuket
# Processing Record 2 of Set 12 | khiri mat
# Processing Record 3 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 4 of Set 12 | tara
# Processing Record 5 of Set 12 | itoman
# Processing Record 6 of Set 12 | hurghada
# Processing Record 7 of Set 12 | oktyabrskoye
# Processing Record 8 of Set 12 | lieksa
# Processing Record 9 of Set 12 | tual
# Processing Record 10 of Set 12 | muros
# Processing Record 11 of Set 12 | shimoda
# Processing Record 12 of Set 12 | guerrero negro
# Processing Record 13 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 12 | jumla
# Processing Record 15 of Set 12 | kendari
# Processing Record 16 of Set 12 | akdepe
# Processing Record 17 of Set 12 | outjo
# Processing Record 18 of Set 12 | pakxan
# Processing Record 19 of Set 12 | andros town
# Processing Record 20 of Set 12 | fort-shevchenko
# Processing Record 21 of Set 12 | uchiza
# Processing Record 22 of Set 12 | tornio
# Processing Record 23 of Set 12 | luganville
# Processing Record 24 of Set 12 | mwinilunga
# Processing Record 25 of Set 12 | pemangkat
# Processing Record 26 of Set 12 | arlit
# Processing Record 27 of Set 12 | roebourne
# Processing Record 28 of Set 12 | assare
# Processing Record 29 of Set 12 | alamosa
# Processing Record 30 of Set 12 | shepsi
# Processing Record 31 of Set 12 | baghdad
# Processing Record 32 of Set 12 | waipawa
# Processing Record 33 of Set 12 | atar
# Processing Record 34 of Set 12 | lagoa
# Processing Record 35 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 36 of Set 12 | derzhavinsk
# Processing Record 37 of Set 12 | dembi dolo
# Processing Record 38 of Set 12 | bur gabo
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a new DataFrame.

city_data_df = pd.DataFrame(city_data)
city_data_df['Rain inches (last 3 hrs)'] = city_data_df['Rain inches (last 3 hrs)'] / 25.4
city_data_df['Snow inches (last 3 hrs)'] = city_data_df['Snow inches (last 3 hrs)'] / 25.4
city_data_df.head(10)
# Out:
#             City Country                 Date    Lat     Lng  Max Temp  \
# 0          Kapaa      US  2020-04-20 06:47:07  22.08 -159.32     75.20
# 1   Longyearbyen      SJ  2020-04-20 06:42:31  78.22   15.64     21.20
# 2      Cape Town      ZA  2020-04-20 06:46:00 -33.93   18.42     63.00
# 3   Puerto Ayora      EC  2020-04-20 06:47:08  -0.74  -90.35     79.00
# 4       Show Low      US  2020-04-20 06:47:08  34.25 -110.03     43.00
# 5      Saskylakh      RU  2020-04-20 06:47:08  71.92  114.08     25.97
# 6        Rikitea      PF  2020-04-20 06:47:08 -23.12 -134.97     76.80
# 7      Busselton      AU  2020-04-20 06:47:08 -33.65  115.33     66.99
# 8  San Cristobal      VE  2020-04-20 06:47:09   7.77  -72.22     66.31
# 9     Sao Filipe      CV  2020-04-20 06:47:09  14.90  -24.50     70.47
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        69          75        2.28       broken clouds
# 1        79          75       20.80         shower rain
# 2        77          75       16.11       broken clouds
# 3        87          65        5.99       broken clouds
# 4        52           1        9.17           clear sky
# 5        95          16        3.09          few clouds
# 6        71          61        6.62       broken clouds
# 7        73          97        8.99          light rain
# 8        63          84        1.34          light rain
# 9        75           0       15.88           clear sky
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                  0.000000                       0.0
# 1                  0.000000                       0.0
# 2                  0.000000                       0.0
# 3                  0.000000                       0.0
# 4                  0.000000                       0.0
# 5                  0.000000                       0.0
# 6                  0.000000                       0.0
# 7                  0.011811                       0.0
# 8                  0.024016                       0.0
# 9                  0.000000                       0.0

# %%
# Save the new DataFrame as a CSV file to be used for Part 2.
output_data_file = "weather_data/WeatherPy_challenge.csv"
city_data_df.to_csv(output_data_file, index_label = "City_ID")

# %%
# How many cities have recorded rainfall?

city_rain = city_data_df.loc[city_data_df['Rain inches (last 3 hrs)'] > 0]
city_rain['Rain inches (last 3 hrs)'].count()
# Out:
# 77

# %%
# How many cities have recorded snow?

city_snow = city_data_df.loc[city_data_df['Snow inches (last 3 hrs)'] > 0]
city_snow['Snow inches (last 3 hrs)'].count()
# Out:
# 13

# %%
# Format the DataFrame.

city_data_df['Rain inches (last 3 hrs)'] = city_data_df['Rain inches (last 3 hrs)'].map('{:.3f}'.format)
city_data_df['Snow inches (last 3 hrs)'] = city_data_df['Snow inches (last 3 hrs)'].map('{:.0f}'.format)

city_data_df.head(10)
# Out:
#             City Country                 Date    Lat     Lng  Max Temp  \
# 0          Kapaa      US  2020-04-20 06:47:07  22.08 -159.32     75.20
# 1   Longyearbyen      SJ  2020-04-20 06:42:31  78.22   15.64     21.20
# 2      Cape Town      ZA  2020-04-20 06:46:00 -33.93   18.42     63.00
# 3   Puerto Ayora      EC  2020-04-20 06:47:08  -0.74  -90.35     79.00
# 4       Show Low      US  2020-04-20 06:47:08  34.25 -110.03     43.00
# 5      Saskylakh      RU  2020-04-20 06:47:08  71.92  114.08     25.97
# 6        Rikitea      PF  2020-04-20 06:47:08 -23.12 -134.97     76.80
# 7      Busselton      AU  2020-04-20 06:47:08 -33.65  115.33     66.99
# 8  San Cristobal      VE  2020-04-20 06:47:09   7.77  -72.22     66.31
# 9     Sao Filipe      CV  2020-04-20 06:47:09  14.90  -24.50     70.47
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        69          75        2.28       broken clouds
# 1        79          75       20.80         shower rain
# 2        77          75       16.11       broken clouds
# 3        87          65        5.99       broken clouds
# 4        52           1        9.17           clear sky
# 5        95          16        3.09          few clouds
# 6        71          61        6.62       broken clouds
# 7        73          97        8.99          light rain
# 8        63          84        1.34          light rain
# 9        75           0       15.88           clear sky
#
#   Rain inches (last 3 hrs) Snow inches (last 3 hrs)
# 0                    0.000                        0
# 1                    0.000                        0
# 2                    0.000                        0
# 3                    0.000                        0
# 4                    0.000                        0
# 5                    0.000                        0
# 6                    0.000                        0
# 7                    0.012                        0
# 8                    0.024                        0
# 9                    0.000                        0
